# %%
from mpl_toolkits.axes_grid1.parasite_axes import host_subplot
from mpl_toolkits.axisartist.axislines import Axes
from scipy.sparse.csr import csr_matrix
from sklearn import datasets
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error
from sklearn.svm.classes import NuSVR
from sklearn.ensemble.gradient_boosting import GradientBoostingRegressor
from sklearn.linear_model.stochastic_gradient import SGDClassifier
from sklearn.metrics import hamming_loss
import locale, time
# locale.setlocale(locale.LC_TIME, "fr_FR".encode('ascii'))
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
# from matplotlib import rc
# from __future__ import unicode_literals
import numpy as np
import matplotlib
# matplotlib.rcParams['text.usetex'] = True
# matplotlib.rcParams['text.latex.unicode'] = True
# rc('font',**{'family':'serif','serif':['Times']})

# %matplotlib nbagg


rhoair = 1.2
Cp = 16/27
Rayon_Palles = 101
pi=3.1415
puissCoeff = 0.5*Cp*pi*rhoair*Rayon_Palles*Rayon_Palles
Nseries = 5

donnees = pd.read_csv('Results_Used_QN2_Working_04-2015_04-2017.csv',sep=";")
donnees['Date'] = pd.to_datetime(donnees['Date'],infer_datetime_format=True)
donnees = donnees.set_index(['Date'])
df = [pd.DataFrame() for i in range(Nseries)]
for i in range(Nseries):
    df[i]["Puissance_Active"] = donnees["Active_Power_QN2" + str(i+1) + "-mean"]
    df[i]["Vitesse_Vent"] = donnees["Wind_Speed_QN2" + str(i+1) + "-mean"]
    df[i]["Puissance_Vent"] = puissCoeff*df[i].Vitesse_Vent**3

    # mise à l'échelle de la puissance active
    mask = df[i]["Puissance_Active"] > 10000
    df[i]["Puissance_Active"][mask] /= 1000

    df[i]["Rendement"] = df[i].Puissance_Active*1000/df[i].Puissance_Vent
    mask1 = df[i]["Puissance_Active"] < 0
    df[i]["Rendement"][mask1] = 0
    mask2 = df[i]["Rendement"] > 1.00
    df[i]["Rendement"][mask2] /= 10 

plt.plot(df[4]["Vitesse_Vent"],df[4]["Rendement"])
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# # Exemple d'utilisation des dates

# %%
# les mois, jours, etc. sont dans donnees.index (ou df[i].index)
donnees.index.month

# on peut faire des masques :
mask = df[i].index.month < 6
df[i][mask].describe()
# Out:
#        Puissance_Active  Vitesse_Vent  Puissance_Vent     Rendement
# count      43310.000000  43310.000000    4.331000e+04  4.331000e+04
# mean         216.846443      5.572313    3.799405e+06          -inf
# std          273.114369      2.904143    6.574743e+06           NaN
# min          -20.469151      0.000000    0.000000e+00          -inf
# 25%            1.702964      3.487776    4.834295e+05  1.958200e-04
# 50%           90.525528      5.244544    1.643654e+06  1.571233e-01
# 75%          369.623619      7.207240    4.265738e+06  2.162108e-01
# max          999.997620     22.478371    1.294142e+08  8.882615e-01

# %%
x
# Out:
#        ID               TimeOn         TimeOnString              TimeOff  \
# 0  283653  2017-04-17 17:01:11  2017-04-17T17:01:11  2017-04-17 17:04:41
# 1  283645  2017-04-17 16:47:07  2017-04-17T16:47:07  2017-04-17 16:56:19
# 2  283613  2017-04-17 10:16:12  2017-04-17T10:16:12  2017-04-17 10:21:12
# 3  283595  2017-04-16 20:14:48  2017-04-16T20:14:48  2017-04-16 20:18:18
# 4  283587  2017-04-16 20:11:53  2017-04-16T20:11:53  2017-04-16 20:15:23
#
#    DurationSec  AlarmGroup AlarmGroupText  Name  StationNr  LogType  \
# 0          210           1        Turbine  QN24    2305412        0
# 1          552           1        Turbine  QN24    2305412        0
# 2          300           1        Turbine  QN24    2305412        0
# 3          210           1        Turbine  QN22    2305414        0
# 4          210           1        Turbine  QN25    2305411        0
#
#    Alarmcode                    AlarmText  Designator  Parameter UserName  \
# ...

# %%
donnees_alarm = pd.read_csv('QN2_Alarms.csv',sep=";")

donnees_alarm['TimeOn'] = pd.to_datetime(donnees_alarm['TimeOn'],infer_datetime_format=True)
donnees_alarm['TimeOff'] = pd.to_datetime(donnees_alarm['TimeOff'],infer_datetime_format=True)

Alarm = [pd.DataFrame() for i in range(Nseries)]
mask1 = donnees_alarm.Name == 'QN21'
mask2 = donnees_alarm.Name == 'QN22'
mask3 = donnees_alarm.Name == 'QN23'
mask4 = donnees_alarm.Name == 'QN24'
mask5 = donnees_alarm.Name == 'QN25'
Alarm[0] = donnees_alarm[mask1]
Alarm[1] = donnees_alarm[mask2]
Alarm[2] = donnees_alarm[mask3]
Alarm[3] = donnees_alarm[mask4]
Alarm[4] = donnees_alarm[mask5]

Alarm[0].TimeOn
# Out:
# 10     2017-04-13 03:33:38
# 22     2017-04-08 09:18:47
# 23     2017-04-08 02:05:29
# 24     2017-04-08 01:56:00
# 30     2017-04-06 16:53:31
# 39     2017-04-06 14:00:50
# 44     2017-04-06 14:00:46
# 52     2017-04-04 09:34:59
# 55     2017-04-04 09:13:28
# 58     2017-04-04 08:38:04
# 63     2017-04-04 08:34:55
# 68     2017-04-04 08:34:47
# 76     2017-04-04 08:34:46
# 85     2017-04-04 08:34:45
# 86     2017-04-04 08:34:45
# 88     2017-04-04 08:34:44
# 92     2017-04-04 07:25:37
# 96     2017-04-03 21:53:41
# 104    2017-03-29 21:53:31
# 112    2017-03-25 13:30:06
# 115    2017-03-24 21:53:52
# 118    2017-03-22 23:08:25
# 127    2017-03-19 21:53:42
# 141    2017-03-14 05:13:31
# 147    2017-03-10 01:38:08
# 151    2017-03-09 05:13:51
# 165    2017-03-03 13:33:40
# 173    2017-02-28 02:49:28
# 174    2017-02-28 02:46:57
# 176    2017-02-27 15:24:43
#                ...
# 3255   2015-06-20 19:11:44
# 3260   2015-06-16 16:53:46
# 3265   2015-06-12 05:14:44
# ...

# %%
donnees_alarm['TimeOn'] = pd.to_datetime(donnees_alarm['TimeOn'],infer_datetime_format=True)
donnees_alarm['TimeOff'] = pd.to_datetime(donnees_alarm['TimeOff'],infer_datetime_format=True)
